# %%
from datasets import load_dataset
from IPython.display import Audio as AudioDisplay
from torchmetrics.functional.audio.pesq import perceptual_evaluation_speech_quality as pesq
from transformers import AutoFeatureExtractor, MimiModel, DacModel, AutoProcessor
import torch

# %%
from codec_latent_denoiser import CodecLatentDenoiser

# %%
model = CodecLatentDenoiser.from_pretrained("gokulkarthik/codec-latent-denoiser-default")
model
# Out:
# config.json:   0%|          | 0.00/814 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/157M [00:00<?, ?B/s]
# Some weights of the model checkpoint at gokulkarthik/codec-latent-denoiser-default were not used when initializing CodecLatentDenoiser: ['denoiser.layer1.bias', 'denoiser.layer2.bias', 'denoiser.layer_norm.bias']
# - This IS expected if you are initializing CodecLatentDenoiser from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CodecLatentDenoiser from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# CodecLatentDenoiser(
#   (codec): DacModel(
#     (encoder): DacEncoder(
#       (conv1): Conv1d(1, 64, kernel_size=(7,), stride=(1,), padding=(3,))
#       (block): ModuleList(
#         (0): DacEncoderBlock(
#           (res_unit1): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(64, 64, kernel_size=(7,), stride=(1,), padding=(3,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#           )
#           (res_unit2): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(64, 64, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#           )
#           (res_unit3): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(64, 64, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#           )
#           (snake1): Snake1d()
#           (conv1): Conv1d(64, 128, kernel_size=(4,), stride=(2,), padding=(1,))
#         )
#         (1): DacEncoderBlock(
#           (res_unit1): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(3,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#           )
#           (res_unit2): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#           )
#           (res_unit3): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(128, 128, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#           )
#           (snake1): Snake1d()
#           (conv1): Conv1d(128, 256, kernel_size=(8,), stride=(4,), padding=(2,))
#         )
#         (2): DacEncoderBlock(
#           (res_unit1): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(3,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#           )
#           (res_unit2): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#           )
#           (res_unit3): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(256, 256, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#           )
#           (snake1): Snake1d()
#           (conv1): Conv1d(256, 512, kernel_size=(10,), stride=(5,), padding=(3,))
#         )
#         (3): DacEncoderBlock(
#           (res_unit1): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(512, 512, kernel_size=(7,), stride=(1,), padding=(3,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#           )
#           (res_unit2): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(512, 512, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#           )
#           (res_unit3): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(512, 512, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#           )
#           (snake1): Snake1d()
#           (conv1): Conv1d(512, 1024, kernel_size=(16,), stride=(8,), padding=(4,))
#         )
#       )
#       (snake1): Snake1d()
#       (conv2): Conv1d(1024, 1024, kernel_size=(3,), stride=(1,), padding=(1,))
#     )
#     (decoder): DacDecoder(
#       (conv1): Conv1d(1024, 1536, kernel_size=(7,), stride=(1,), padding=(3,))
#       (block): ModuleList(
#         (0): DacDecoderBlock(
#           (snake1): Snake1d()
#           (conv_t1): ConvTranspose1d(1536, 768, kernel_size=(16,), stride=(8,), padding=(4,))
#           (res_unit1): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(768, 768, kernel_size=(7,), stride=(1,), padding=(3,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(768, 768, kernel_size=(1,), stride=(1,))
#           )
#           (res_unit2): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(768, 768, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(768, 768, kernel_size=(1,), stride=(1,))
#           )
#           (res_unit3): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(768, 768, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(768, 768, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (1): DacDecoderBlock(
#           (snake1): Snake1d()
#           (conv_t1): ConvTranspose1d(768, 384, kernel_size=(10,), stride=(5,), padding=(3,))
#           (res_unit1): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(384, 384, kernel_size=(7,), stride=(1,), padding=(3,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#           )
#           (res_unit2): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(384, 384, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#           )
#           (res_unit3): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(384, 384, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(384, 384, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (2): DacDecoderBlock(
#           (snake1): Snake1d()
#           (conv_t1): ConvTranspose1d(384, 192, kernel_size=(8,), stride=(4,), padding=(2,))
#           (res_unit1): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(192, 192, kernel_size=(7,), stride=(1,), padding=(3,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#           )
#           (res_unit2): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(192, 192, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#           )
#           (res_unit3): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(192, 192, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (3): DacDecoderBlock(
#           (snake1): Snake1d()
#           (conv_t1): ConvTranspose1d(192, 96, kernel_size=(4,), stride=(2,), padding=(1,))
#           (res_unit1): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(96, 96, kernel_size=(7,), stride=(1,), padding=(3,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(96, 96, kernel_size=(1,), stride=(1,))
#           )
#           (res_unit2): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(96, 96, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(96, 96, kernel_size=(1,), stride=(1,))
#           )
#           (res_unit3): DacResidualUnit(
#             (snake1): Snake1d()
#             (conv1): Conv1d(96, 96, kernel_size=(7,), stride=(1,), padding=(27,), dilation=(9,))
#             (snake2): Snake1d()
#             (conv2): Conv1d(96, 96, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (snake1): Snake1d()
#       (conv2): Conv1d(96, 1, kernel_size=(7,), stride=(1,), padding=(3,))
#       (tanh): Tanh()
#     )
#     (quantizer): DacResidualVectorQuantize(
#       (quantizers): ModuleList(
#         (0-11): 12 x DacVectorQuantize(
#           (in_proj): Conv1d(1024, 8, kernel_size=(1,), stride=(1,))
#           (out_proj): Conv1d(8, 1024, kernel_size=(1,), stride=(1,))
#           (codebook): Embedding(1024, 8)
#         )
#       )
#     )
#   )
#   (denoiser): MLPDenoiser(
#     (layer1): Linear(in_features=1024, out_features=2048, bias=False)
#     (layer2): Linear(in_features=2048, out_features=1024, bias=False)
#     (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (activation): GELU(approximate='none')
#     (dropout): Dropout(p=0.05, inplace=False)
#   )
# )

# %%
data_path = "JacobLinCool/VoiceBank-DEMAND-16k"

# %%
ds = load_dataset("JacobLinCool/VoiceBank-DEMAND-16k", num_proc=32)
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'clean', 'noisy'],
#         num_rows: 11572
#     })
#     test: Dataset({
#         features: ['id', 'clean', 'noisy'],
#         num_rows: 824
#     })
# })

# %%
sample_idx = 0
sample = ds['train'][sample_idx]
sample
# Out:
# {'id': 'p226_001',
#  'clean': {'path': 'p226_001.wav',
#   'array': array([-0.00286865, -0.00497437, -0.00469971, ..., -0.00201416,
#          -0.00152588, -0.00021362], shape=(36480,)),
#   'sampling_rate': 16000},
#  'noisy': {'path': 'p226_001.wav',
#   'array': array([-0.00283813, -0.00488281, -0.00473022, ...,  0.006073  ,
#           0.00564575,  0.00540161], shape=(36480,)),
#   'sampling_rate': 16000}}

# %%
AudioDisplay(sample['clean']['array'], rate=sample['clean']['sampling_rate'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
AudioDisplay(sample['noisy']['array'], rate=sample['noisy']['sampling_rate'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
preds = torch.from_numpy(sample['noisy']['array'])
target = torch.from_numpy(sample['clean']['array'])
sampling_rate = sample['noisy']['sampling_rate']
assert sampling_rate == 16000
print(preds.shape, target.shape)
score = pesq(preds=preds, target=target, fs=sampling_rate, mode="wb").item()
print(score)
# Out:
# torch.Size([36480]) torch.Size([36480])
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 6
#       4 assert sampling_rate == 16000
#       5 print(preds.shape, target.shape)
# ----> 6 score = pesq(preds=preds, target=target, fs=sampling_rate, mode="wb").item()
#       7 print(score)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/torchmetrics/functional/audio/pesq.py:83, in perceptual_evaluation_speech_quality(preds, target, fs, mode, keep_same_device, n_processes)
#      34 r"""Calculate `Perceptual Evaluation of Speech Quality`_ (PESQ).
#      35
#      36 It's a recognized industry standard for audio quality that takes into considerations characteristics such as: audio
#    (...)     80
#      81 """
#      82 if not _PESQ_AVAILABLE:
# ---> 83     raise ModuleNotFoundError(
#      84         "PESQ metric requires that pesq is installed."
#      85         " Either install as `pip install torchmetrics[audio]` or `pip install pesq`."
#      86     )
#      87 import pesq as pesq_backend
#      89 def _issubtype_number(x: Any) -> bool:
#
# ModuleNotFoundError: PESQ metric requires that pesq is installed. Either install as `pip install torchmetrics[audio]` or `pip install pesq`.

# %%
score = pesq(preds=preds, target=preds, fs=sampling_rate, mode="wb").item()
print(score)
score = pesq(preds=target, target=target, fs=sampling_rate, mode="wb").item()
print(score)
score = pesq(preds=target, target=preds, fs=sampling_rate, mode="wb").item()
print(score)
# Out:
# 4.643888473510742
# 4.643888473510742
# 1.1161136627197266

# %% [markdown]
# # Let's try DAC

# %%
dac_model_path = "descript/dac_16khz"
dac_model = DacModel.from_pretrained(dac_model_path)
dac_processor = AutoProcessor.from_pretrained(dac_model_path)
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.

# %%
def dac_forward(audio_sample, n_quantizers=12):
    global dac_model, dac_processor

    inputs = dac_processor(raw_audio=audio_sample, sampling_rate=dac_processor.sampling_rate, return_tensors="pt")
    encoder_outputs = dac_model.encode(inputs["input_values"], n_quantizers=n_quantizers)
    audio_values = dac_model.decode(quantized_representation=encoder_outputs.quantized_representation).audio_values.cpu().detach()[0]

    audio_values_tensor = torch.zeros_like(audio_sample)
    audio_values_tensor[:audio_values.shape[0]] = audio_values
    
    return audio_values_tensor

# %%
noisy = torch.from_numpy(sample['noisy']['array'])
clean = torch.from_numpy(sample['clean']['array'])
noisy_transformed = dac_forward(noisy)
clean_transformed = dac_forward(clean)
assert clean.shape == clean_transformed.shape
assert noisy.shape == noisy_transformed.shape

# %%
AudioDisplay(clean, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
AudioDisplay(noisy, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
AudioDisplay(clean_transformed, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
AudioDisplay(noisy_transformed, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# how much does dac preserve pesq?
print(pesq(preds=clean_transformed, target=clean, fs=sampling_rate, mode="wb").item())
print(pesq(preds=noisy_transformed, target=noisy, fs=sampling_rate, mode="wb").item())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 2
#       1 # how much does dac preserve pesq?
# ----> 2 print(pesq(preds=clean_transformed, target=clean, fs=sampling_rate, mode="wb").item())
#       3 print(pesq(preds=noisy_transformed, target=noisy, fs=sampling_rate, mode="wb").item())
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/torchmetrics/functional/audio/pesq.py:83, in perceptual_evaluation_speech_quality(preds, target, fs, mode, keep_same_device, n_processes)
#      34 r"""Calculate `Perceptual Evaluation of Speech Quality`_ (PESQ).
#      35
#      36 It's a recognized industry standard for audio quality that takes into considerations characteristics such as: audio
#    (...)     80
#      81 """
#      82 if not _PESQ_AVAILABLE:
# ---> 83     raise ModuleNotFoundError(
#      84         "PESQ metric requires that pesq is installed."
#      85         " Either install as `pip install torchmetrics[audio]` or `pip install pesq`."
#      86     )
#      87 import pesq as pesq_backend
#      89 def _issubtype_number(x: Any) -> bool:
#
# ModuleNotFoundError: PESQ metric requires that pesq is installed. Either install as `pip install torchmetrics[audio]` or `pip install pesq`.

# %%
print(pesq(preds=noisy, target=clean, fs=sampling_rate, mode="wb").item())
print(pesq(preds=noisy_transformed, target=clean, fs=sampling_rate, mode="wb").item())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(pesq(preds=noisy, target=clean, fs=sampling_rate, mode="wb").item())
#       2 print(pesq(preds=noisy_transformed, target=clean, fs=sampling_rate, mode="wb").item())
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages/torchmetrics/functional/audio/pesq.py:83, in perceptual_evaluation_speech_quality(preds, target, fs, mode, keep_same_device, n_processes)
#      34 r"""Calculate `Perceptual Evaluation of Speech Quality`_ (PESQ).
#      35
#      36 It's a recognized industry standard for audio quality that takes into considerations characteristics such as: audio
#    (...)     80
#      81 """
#      82 if not _PESQ_AVAILABLE:
# ---> 83     raise ModuleNotFoundError(
#      84         "PESQ metric requires that pesq is installed."
#      85         " Either install as `pip install torchmetrics[audio]` or `pip install pesq`."
#      86     )
#      87 import pesq as pesq_backend
#      89 def _issubtype_number(x: Any) -> bool:
#
# ModuleNotFoundError: PESQ metric requires that pesq is installed. Either install as `pip install torchmetrics[audio]` or `pip install pesq`.

# %% [markdown]
# ## Batch operations
